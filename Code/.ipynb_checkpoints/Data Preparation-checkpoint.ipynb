# %%
# BERT REF : https://github.com/hooshvare/parsbert#parsbert-v20-sentiment-analysis
# !pip install -q hazm
# !pip install -q clean-text[gpl]
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-4.14.3-py2.py3-none-any.whl (13.2 MB)
# Requirement already satisfied: six in d:\apps\anaconda3\envs\torch\lib\site-packages (from plotly) (1.15.0)
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11429 sha256=c2e9e88792ee15cce47703a80c4f973f4419ad823f8a3d4378c5d0333d28655b
#   Stored in directory: c:\users\ali\appdata\local\pip\cache\wheels\ac\cb\8a\b27bf6323e2f4c462dcbf77d70b7c5e7868a7fbe12871770cf
# Successfully built retrying
# Installing collected packages: retrying, plotly
# Successfully installed plotly-4.14.3 retrying-1.3.3

# %% [markdown]
# ## Import

# %%
DATA_PATH = '../Dataset/DeepSentiPers-original.csv'
import pandas as pd
import hazm
import csv, re, pickle

import plotly.express as px
import plotly.graph_objects as go

from sklearn.model_selection import train_test_split

# %%
def print_duplicate_by_column(df, col_name):
    ids = df[col_name]
    dup_df = df[ids.isin(ids[ids.duplicated()])].sort_values(col_name)
    pd.set_option('display.max_rows', df.shape[0]+1)
    return dup_df

# %% [markdown]
# # Load and analyze data

# %%
df = pd.read_csv(DATA_PATH,names =['comment', 'sentiment'], encoding='utf-8')
df.head()
# Out:
#                                              comment  sentiment
# 0  گوشي خوبيه(قوي و شکيل و زيبا و بي رقيب)البته ت...          1
# 1                              سلام خيلي خوبه بخرين.          2
# 2  از جمله قابلیت‌های ارتباطی HTC Desire SV می‌تو...          0
# 3  نهایتا،  یک دوربین VGA نیز برای انجام مکالمات ...          0
# 4  من حدوداً ۱ ماهي‌ که مي‌شه اين گوشي رو دارم، ر...          1

# %% [markdown]
# ### Check None values

# %%
# print data information
print('data information')
print(df.info(), '\n')

# print missing values information
print('missing values stats')
print(df.isnull().sum(), '\n')
# Out:
# data information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5561 entries, 0 to 5560
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   comment    5561 non-null   object
#  1   sentiment  5561 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 87.0+ KB
# None
#
# missing values stats
# comment      0
# sentiment    0
# dtype: int64

# %% [markdown]
# ## Check duplicates

# %%
print_duplicate_by_column(df,'comment')
# Out:
#                                                 comment  sentiment
# 57                     "محدوديت بزرگترين کابوس بشر است!          0
# 5231                   "محدوديت بزرگترين کابوس بشر است!          0
# 1030                              ( با بهره گيري از مک.          0
# 1704                              ( با بهره گيري از مک.          0
# 3282  (البته الان با وجود برنامه سيب اين کار راحتتر ...          1
# 4615  (البته الان با وجود برنامه سيب اين کار راحتتر ...          0
# 3009                                           )بگذريم.          0
# 2520                                           )بگذريم.          0
# 4017  ***** آپديت ***** سي و يک شهريور : پردازنده ي ...          0
# 1329  ***** آپديت ***** سي و يک شهريور : پردازنده ي ...          1
# 3794  3- مدل HD Surf HERO مدلی است که ویژه انواع ورز...          0
# 1196  3- مدل HD Surf HERO مدلی است که ویژه انواع ورز...          0
# 1059  GoPro HD HERO نام دوربین فیلم برداری جدید شرکت...          0
# 3423  GoPro HD HERO نام دوربین فیلم برداری جدید شرکت...          0
# 4038  آیا تا به حال اتفاق افتاده است که کاری خارق ال...          0
# 480   آیا تا به حال اتفاق افتاده است که کاری خارق ال...          0
# 1366              آیا هیجان و ماجراجویی مرزی مشخص دارد؟          0
# 630               آیا هیجان و ماجراجویی مرزی مشخص دارد؟          0
# 1575  از قابلیت‌های کاربردی این سیستم عامل می‌توان ب...          0
# 3885  از قابلیت‌های کاربردی این سیستم عامل می‌توان ب...          1
# 5099  از نظر کیفیت ساخت و استحکام نیز به ممد استفاده...          2
# 89    از نظر کیفیت ساخت و استحکام نیز به ممد استفاده...          1
# 5213  اصلی‌ترین تغییر ایجاد شده در سیستم عامل ویندوز...          1
# 2934  اصلی‌ترین تغییر ایجاد شده در سیستم عامل ویندوز...          0
# 2335  اصولا همه ی پارامترها از جمله نوردهی،  فوکوس، ...          1
# 4957  اصولا همه ی پارامترها از جمله نوردهی،  فوکوس، ...          1
# 4231  البته شرکت سازنده یک نمایشگر LCD مخصوص برای ای...          0
# 3036  البته شرکت سازنده یک نمایشگر LCD مخصوص برای ای...          0
# 855   البته هر کسی که آشنایی با دوربین های ضد آب دار...          1
# 4193  البته هر کسی که آشنایی با دوربین های ضد آب دار...          2
# 179   اما از اون 49 درصد گوشي android ي شايد 10 درصد...          0
# 1837  اما از اون 49 درصد گوشي android ي شايد 10 درصد...          0
# 3307  اما در مورد دقت لمسی آن،  به نظر ما با وجود به...          0
# 1769  اما در مورد دقت لمسی آن،  به نظر ما با وجود به...          0
# 523   اما راز موفقیت این دوربین در ثبت لحظات ورزشی د...          0
# 803   اما راز موفقیت این دوربین در ثبت لحظات ورزشی د...          0
# 371   اما علاوه بر کوچک و سبک وزن بودن باید بتوان به...          1
# 3840  اما علاوه بر کوچک و سبک وزن بودن باید بتوان به...          0
# 4772  اولين ضعف اين گوشي صداي اسپيکر پشت گوشي مي باش...          0
# 881   اولين ضعف اين گوشي صداي اسپيکر پشت گوشي مي باش...          0
# 4485  اولين قسمت اين چيپ‌ست به واحد پردازش گرافيکي م...          0
# 3496  اولين قسمت اين چيپ‌ست به واحد پردازش گرافيکي م...          0
# 5113  اين انعطاف پذيري شامل os،  دسترسيه سريع ،  تبا...          0
# 5285  اين انعطاف پذيري شامل os،  دسترسيه سريع ،  تبا...          0
# 1408  اين حافظه همانند واحد پردازش گرافيکي،  از فن‌آ...          0
# 1948  اين حافظه همانند واحد پردازش گرافيکي،  از فن‌آ...          0
# 848   اين دقيقا کاريست که توسط developer ها انجام مي...          0
# 3196  اين دقيقا کاريست که توسط developer ها انجام مي...          0
# 4414  اين پرونده‌ي گرافيکي به نام رمز C1 و گاهي R500...          0
# 2699  اين پرونده‌ي گرافيکي به نام رمز C1 و گاهي R500...          0
# 2929  اين گوشي در کنسول XBOX 360 به کانکتوري که در ز...          1
# 1492  اين گوشي در کنسول XBOX 360 به کانکتوري که در ز...          1
# 326   اينها حقوقي کاملا پيش پا افتاده است که هر شرکت...          0
# 3430  اينها حقوقي کاملا پيش پا افتاده است که هر شرکت...          0
# 2131  اپل (و تا حد زيادي نوکيا) هميشه ثابت کرده که چ...          0
# 3918  اپل (و تا حد زيادي نوکيا) هميشه ثابت کرده که چ...          1
# 5498  اپل بهترين سخت افزارو داره در صورتي که يکي از ...          2
# 3626  اپل بهترين سخت افزارو داره در صورتي که يکي از ...          0
# 3366  اگر به دنبال فیلم برداری با سرعت بالاتری هستید...          1
# 3497  اگر به دنبال فیلم برداری با سرعت بالاتری هستید...          1
# 3582  این دوربین با توجه به نوع کاربرد و فعالیتی که ...          0
# 1312  این دوربین با توجه به نوع کاربرد و فعالیتی که ...          0
# 651   این دوربین فیلم برداری به راحتی تقریبا در هر م...          1
# 3953  این دوربین فیلم برداری به راحتی تقریبا در هر م...          1
# 424   این دوربین مقام پرفروش ترین دوربین ورزشی جهان ...          2
# 4058  این دوربین مقام پرفروش ترین دوربین ورزشی جهان ...          1
# 662                        این یک رکورد شگفت انگیز است.          1
# 3569                       این یک رکورد شگفت انگیز است.          1
# 907   با اين که من يک اپلي هستم ولي هميشه حرف راست ر...          0
# 395   با اين که من يک اپلي هستم ولي هميشه حرف راست ر...          0
# 4189  با این حال با توجه به ساختار پلاستیکی آن،  نبا...         -1
# 3379  با این حال با توجه به ساختار پلاستیکی آن،  نبا...         -1
# 1489  با این دو دکمه و نمایشگر LCD کوچکی که جلوی دور...          1
# 3296  با این دو دکمه و نمایشگر LCD کوچکی که جلوی دور...          0
# 2165  با این دوربین امکان عکاسی در حالت‌های مختلف و ...          0
# 4190  با این دوربین امکان عکاسی در حالت‌های مختلف و ...          1
# 3279                               با تشکر از ديجي کالا          1
# 1318                               با تشکر از ديجي کالا          0
# 5411                                           با تشکر.          0
# 5489                                           با تشکر.          0
# 4773                                          با سلام .          0
# 4045                                          با سلام .          0
# 1748                                          با سلام .          0
# 2343                                           با سلام.          0
# 5451                                           با سلام.          0
# 5057                                           با سلام.          0
# 743                                            با سلام.          0
# 1813                                           با سلام.          0
# 612                                            با سلام.          0
# 4477                                           با سلام.          0
# 3522  با سيستم انحصاري خاص مخصوص خودش و يک استاندارد...          0
# 4542  با سيستم انحصاري خاص مخصوص خودش و يک استاندارد...          0
# 2284  با عرض سلام به تمامي دوستان اينجانب به مدت بيس...          0
# 3678  با عرض سلام به تمامي دوستان اينجانب به مدت بيس...          0
# 3589                                 باريکيش حرف نداره.          0
# 3300                                 باريکيش حرف نداره.          1
# 4622                                            باسلام.          0
# 3200                                            باسلام.          0
# 3046                                            باسلام.          0
# 1719  براي اين منظور در صورت اتصال دسته به کنسول XBO...          1
# 5274  براي اين منظور در صورت اتصال دسته به کنسول XBO...          0
# 4525  براي همين است که بهترين کمپاني هاي بازي ساز ما...          0
# 2146  براي همين است که بهترين کمپاني هاي بازي ساز ما...          0
# 3302  برای مثال شما می‌توانید ابعاد کاشی‌های متحرک (...          0
# 205   برای مثال شما می‌توانید ابعاد کاشی‌های متحرک (...          0
# 2067  بعلاوه این دوربین مجهز به لرزش گیر تصویر هم می...          1
# 1311  بعلاوه این دوربین مجهز به لرزش گیر تصویر هم می...          1
# 3672  بنابراین طراحان،  این دوربین را با یک محافظ پل...          1
# 2848  بنابراین طراحان،  این دوربین را با یک محافظ پل...          1
# 2763  به جز این امکانات،  نمی‌توان گفت که ویندوز فون...          0
# 5198  به جز این امکانات،  نمی‌توان گفت که ویندوز فون...          0
# 676   به خصوص ورزش های پر مخاطره مثل قایق سواری آب ه...          0
# 3400  به خصوص ورزش های پر مخاطره مثل قایق سواری آب ه...          0
# 2022                                       به صرفه نيست         -1
# 1644                                       به صرفه نيست         -1
# 3353  به طوری که فقط دو دکمه بر روی بدنه ی آن دیده م...          0
# 1670  به طوری که فقط دو دکمه بر روی بدنه ی آن دیده م...          0
# 5048  به علاوه این تبلت می‌تواند با کیفیت Full HD 10...          1
# 5422  به علاوه این تبلت می‌تواند با کیفیت Full HD 10...          1
# 1988  به علاوه این مرورگر اینترنت به کاربر این امکان...          0
# 2915  به علاوه این مرورگر اینترنت به کاربر این امکان...          0
# 922   به علاوه طراحی این پردازنده به نحویست که گرمای...          0
# 4409  به علاوه طراحی این پردازنده به نحویست که گرمای...          0
# 3841  به هر صورت از آن جایی که کاربری این دوربین به ...          0
# 716   به هر صورت از آن جایی که کاربری این دوربین به ...          0
# 4778  به هر صورت همانطور که گفتیم،  دوربین ورزشی GoP...          2
# 50    به هر صورت همانطور که گفتیم،  دوربین ورزشی GoP...          1
# 4906  به هر ورزشی که قصد دارید بپردازید کافی است که ...          2
# 2153  به هر ورزشی که قصد دارید بپردازید کافی است که ...          2
# 5242  به همین دلیل می‌توان گفت که این تبلت بسیار منا...          2
# 977   به همین دلیل می‌توان گفت که این تبلت بسیار منا...          2
# 3183              بهترين تجربه رو با ايفون5داشته باشين.          0
# 1517              بهترين تجربه رو با ايفون5داشته باشين.          1
# 5534           تاکنون نقدی برای اين محصول درج نشده است.          0
# 115            تاکنون نقدی برای اين محصول درج نشده است.          0
# 4085           تاکنون نقدی برای اين محصول درج نشده است.          0
# 4958           تاکنون نقدی برای اين محصول درج نشده است.          0
# 2327           تاکنون نقدی برای اين محصول درج نشده است.          0
# 2457  تصاویر گرفته شده با دوربین این تبلت کیفیت فوق‌...          2
# 1302  تصاویر گرفته شده با دوربین این تبلت کیفیت فوق‌...          2
# 4930  تغییر اصلی ایجاد شده در صفحه‌ی قفل گوشی (Locks...          0
# 399   تغییر اصلی ایجاد شده در صفحه‌ی قفل گوشی (Locks...          0
# 1740  تفاوتی که شاید تاثیر چشم گیری در کیفیت تصاویر ...          0
# 3452  تفاوتی که شاید تاثیر چشم گیری در کیفیت تصاویر ...          0
# 5345  جزئیات بسیار دقیق هستند،  رنگ‌های تولید شده بس...          2
# 889   جزئیات بسیار دقیق هستند،  رنگ‌های تولید شده بس...          2
# 5235  جواب اين سوال بر ميگرده به چند سال پيش زماني ک...          0
# 5391  جواب اين سوال بر ميگرده به چند سال پيش زماني ک...          0
# 4830  حال ممکن است اين پرسش وجود داشته باشد که آيا ا...          0
# 3710  حال ممکن است اين پرسش وجود داشته باشد که آيا ا...          0
# 3689  حتی عکس‌های پانوراما نیز بسیار شارپ بوده و جزئ...          2
# 2181  حتی عکس‌های پانوراما نیز بسیار شارپ بوده و جزئ...          2
# 321                                           حرف نداره          2
# 4842                                          حرف نداره          1
# 4440  حسگر به کار رفته درون این دوربین از نوع CMOS و...          0
# 2714  حسگر به کار رفته درون این دوربین از نوع CMOS و...          0
# 2892  خدايي بگم , قيمتشم هر چي باشه ارزش داره ديگه م...          1
# 3040  خدايي بگم , قيمتشم هر چي باشه ارزش داره ديگه م...          1
# 2606         خوبي اپل اينه که تکه و هيچ چي مثل اون نيست          1
# 473          خوبي اپل اينه که تکه و هيچ چي مثل اون نيست          1
# 1647                                        خيلي عاليه.          2
# 1101                                        خيلي عاليه.          2
# 783                                         خيلي عاليه.          2
# 3323                                        داغ نميکنه.          1
# 3627                                        داغ نميکنه.          1
# 1757                      در ادامه بیشتر توضیح می‌دهیم.          0
# 748                       در ادامه بیشتر توضیح می‌دهیم.          0
# 4441  در استفاده های معمولی تا دو روز می‌توانید با ی...          1
# 2818  در استفاده های معمولی تا دو روز می‌توانید با ی...          0
# 5037  در این آزمایش دوربین و بالون تا ارتفاع 100 هزا...          0
# 2252  در این آزمایش دوربین و بالون تا ارتفاع 100 هزا...          0
# 2155   در صورت لزوم شما می توانید آن را نیز سفارش دهید.          0
# 296    در صورت لزوم شما می توانید آن را نیز سفارش دهید.          0
# 1502  در ضمن در صورت برخورد دوربین با مکان های مختلف...          1
# 936   در ضمن در صورت برخورد دوربین با مکان های مختلف...          1
# 1286  در قسمت جلو نیز یک دوربین 2 مگاپیکسلی برای مکا...          0
# 1825  در قسمت جلو نیز یک دوربین 2 مگاپیکسلی برای مکا...          0
# 3225  در نهایت دیجی کالا GOPro HD Hero را بهترین دور...          2
# 1577  در نهایت دیجی کالا GOPro HD Hero را بهترین دور...          1
# 3055  در واقع زمان خیلی کمی برای گرفتن یک عکس و سپس ...          1
# 2785  در واقع زمان خیلی کمی برای گرفتن یک عکس و سپس ...          1
# 666   در کل يه محصول ايده آل و خاص براي افراد خاص مي...          1
# 4613  در کل يه محصول ايده آل و خاص براي افراد خاص مي...          1
# 4156  در یک آزمایش که توسط یکی از کاربران این دوربین...          0
# 2927  در یک آزمایش که توسط یکی از کاربران این دوربین...          0
# 3160  دلیل دیگر را هم می توان در لنز بسیار واید دید ...          0
# 5321  دلیل دیگر را هم می توان در لنز بسیار واید دید ...          1
# 5414  دو پد چسبنده ی قوس دار و دو پد مسطح نیز وجود د...          0
# 4703  دو پد چسبنده ی قوس دار و دو پد مسطح نیز وجود د...          0
# 3798  دوستان عزيزي که ميگن آيفون 5 دو هسته اي هست و ...          0
# 4124  دوستان عزيزي که ميگن آيفون 5 دو هسته اي هست و ...          0
# 1245  دومين ضعف دير عمل کردن کليد هاي لمسي پايين صفح...          0
# 64    دومين ضعف دير عمل کردن کليد هاي لمسي پايين صفح...          0
# 2800  دکمه مکالمه یا Home تنها برآمدگی قسمت شیشه‌ای ...          0
# 492   دکمه مکالمه یا Home تنها برآمدگی قسمت شیشه‌ای ...          0
# 2476  دکمه کنترل صدا و دکمه‌ی Power هر کدام در طرفین...          0
# 1200  دکمه کنترل صدا و دکمه‌ی Power هر کدام در طرفین...          0
# 2338  دیافراگم f/2.0 دوربین این گوشی به این معنی است...          2
# 1806  دیافراگم f/2.0 دوربین این گوشی به این معنی است...          2
# 571    رابط کاربری دوربین نیز بسیار ساده و کاربردی است.          2
# 4683   رابط کاربری دوربین نیز بسیار ساده و کاربردی است.          2
# 2838   رابط کاربری دوربین نیز بسیار ساده و کاربردی است.          2
# 3749  رنگ‌های تولید شده بسیار زنده و طبیعی بوده و نو...          1
# 1206  رنگ‌های تولید شده بسیار زنده و طبیعی بوده و نو...          2
# 1201  رنگ‌های تولید شده بسیار زنده و طبیعی بوده و نو...          2
# 4574  سامسونگ تعداد زیادی برنامه کاربردی به طور پیش ...          1
# 2836  سامسونگ تعداد زیادی برنامه کاربردی به طور پیش ...          0
# 4351                                             سلام .          0
# 4172                                             سلام .          0
# 4166                                             سلام .          0
# 637                                              سلام .          0
# 4876                                             سلام .          0
# 4463                                             سلام .          0
# 5532                                             سلام .          0
# 2570                                             سلام .          0
# 5092                                             سلام .          0
# 2369                                    سلام به دوستان.          0
# 3199                                    سلام به دوستان.          0
# 3792                                       سلام به همه.          0
# 4688                                       سلام به همه.          0
# 1823                                              سلام.          0
# 269                                               سلام.          0
# 5221                                              سلام.          0
# 5112                                              سلام.          0
# 4684                                              سلام.          0
# 1537                                              سلام.          0
# 2661                                              سلام.          0
# 2540                                              سلام.          0
# 4600                                              سلام.          0
# 3364                                              سلام.          0
# 4442                                              سلام.          0
# 4946                                              سلام.          0
# 298                                               سلام.          0
# 1462                                              سلام.          0
# 4471  سوما :تصوير فيلمبرداري شده در تمام شرايط تصوير...          0
# 1362  سوما :تصوير فيلمبرداري شده در تمام شرايط تصوير...          0
# 1322  سوني هم مارک خوبيه بنظرم خودم سوني دارم و ازش ...          1
# 4620  سوني هم مارک خوبيه بنظرم خودم سوني دارم و ازش ...          1
# 2636  شرکت مايکروسافت براي آگاهي کاربر از فعال بودن ...          1
# 240   شرکت مايکروسافت براي آگاهي کاربر از فعال بودن ...          1
# 1327  شما می توانید به صورت دستی و با فشردن دکمه ی ش...          0
# 3639  شما می توانید به صورت دستی و با فشردن دکمه ی ش...          0
# 5256  طراحی منحصر به فرد Tegra 3 شامل یک پردازنده چه...          1
# 2068  طراحی منحصر به فرد Tegra 3 شامل یک پردازنده چه...          1
# 4756                                              عالي.          2
# 3503                                              عالي.          2
# 436                                               عالي.          2
# 1246                                             عاليه!          2
# 1987                                             عاليه!          2
# 2680                                             عاليه.          2
# 4794                                             عاليه.          2
# 4499  علاوه بر اين،  قسمت اطلاعاتي که در بخش logic م...          0
# 1004  علاوه بر اين،  قسمت اطلاعاتي که در بخش logic م...          0
# 4355  علاوه بر روش های مختلف اتصال دوربین به بدن ورز...          1
# 1890  علاوه بر روش های مختلف اتصال دوربین به بدن ورز...          1
# 3577  فراموش کنید که هر سه مدل Helmet،  MotorSports،...          0
# 5291  فراموش کنید که هر سه مدل Helmet،  MotorSports،...          0
# 4649           فریب ظاهر ساده و مکعبی شکل آن را نخورید.          0
# 5304           فریب ظاهر ساده و مکعبی شکل آن را نخورید.          0
# 4866  فقط در مورد نورسنجی می توانید انتخاب هایی چون ...          0
# 724   فقط در مورد نورسنجی می توانید انتخاب هایی چون ...          0
# 1844        فلاش LED این دوربین فوق‌العاده قدرتمند است.          2
# 383         فلاش LED این دوربین فوق‌العاده قدرتمند است.          2
# 1650  قطعا کسايي که وضع خوبي داشتن از گوشي هاي Apple...          0
# 3023  قطعا کسايي که وضع خوبي داشتن از گوشي هاي Apple...          0
# 2222  مایکروسافت طراحی ویندوز فون 8 را به بهترین نحو...          1
# 5230  مایکروسافت طراحی ویندوز فون 8 را به بهترین نحو...          1
# 3697  متاسفانه من معتقدم که آينده گوشي ها مالandroid...          0
# 3204  متاسفانه من معتقدم که آينده گوشي ها مالandroid...         -1
# 5000  محیط سیستم عامل کاملا روان است و کاربران کوچک‌...          1
# 3136  محیط سیستم عامل کاملا روان است و کاربران کوچک‌...          1
# 1945        مطالبي که عرض کردم به سادگي قابل قضاوت است!          0
# 4255        مطالبي که عرض کردم به سادگي قابل قضاوت است!          0
# 1233  مطمئن باشید هرگز از سطوحی که به آن متصل شده اس...          1
# 1723  مطمئن باشید هرگز از سطوحی که به آن متصل شده اس...          1
# 5366  مطمئنا برای یک ورزشکار بهترین راه حمل یک دوربی...          0
# 1722  مطمئنا برای یک ورزشکار بهترین راه حمل یک دوربی...          0
# 2161                           ممنون که تا آخرش خوندين.          0
# 4783                           ممنون که تا آخرش خوندين.          0
# 1484  من بزرگ بيشتر دوست دارم ولي نميتونم بزرگي رو ف...          0
# 1591  من بزرگ بيشتر دوست دارم ولي نميتونم بزرگي رو ف...          0
# 860   من که فکر ميکنم اپل شگفتي هاي بعديش رو براي مح...          0
# 2026  من که فکر ميکنم اپل شگفتي هاي بعديش رو براي مح...          0
# 4119  موضوعی که از نظر بسیاری یکی از نقاط ضعف جدی ای...         -1
# 593   موضوعی که از نظر بسیاری یکی از نقاط ضعف جدی ای...         -1
# 4015                                         موفق باشيد          0
# 2982                                         موفق باشيد          1
# 2783                                         موفق باشيد          0
# 2507                                        موفق باشيد.          0
# 2594                                        موفق باشيد.          0
# 5216                                        موفق باشيد.          0
# 2215                                        موفق باشيد.          0
# 78                                           موفق باشين          1
# 4988                                         موفق باشين          0
# 1610                                         موفق باشين          0
# 5421  همانند عکس‌های گرفته شده،  کیفیت فیلم‌برداری ا...          2
# 1291  همانند عکس‌های گرفته شده،  کیفیت فیلم‌برداری ا...          2
# 926   همانگونه که ميدانيد شرکت مايکرو سافت از همان ف...         -1
# 244   همانگونه که ميدانيد شرکت مايکرو سافت از همان ف...         -1
# 1694  همچنین تایمر و توانایی عکاسی پیاپی با سرعت 3 ف...          0
# 5082  همچنین تایمر و توانایی عکاسی پیاپی با سرعت 3 ف...          0
# 4084  همچنین تغییر جهت نمایشگر به حالت عمودی و افقی ...          1
# 4555  همچنین تغییر جهت نمایشگر به حالت عمودی و افقی ...          1
# 2071  همچنین تنوع مود بسیار خوبی برای انتخاب مود های...          2
# 4425  همچنین تنوع مود بسیار خوبی برای انتخاب مود های...          2
# 2271  همچنین توسط بسیاری از موسسات و نشریات معتبر به...          2
# 1181  همچنین توسط بسیاری از موسسات و نشریات معتبر به...          1
# 451   هم‌چنين کنسول XBOX 360 از صفحه کليد USB براي ا...          0
# 156   هم‌چنين کنسول XBOX 360 از صفحه کليد USB براي ا...          0
# 4739  و از اينکه ديگران به حقوق من احترام مي گذارند ...          0
# 4283  و از اينکه ديگران به حقوق من احترام مي گذارند ...          0
# 120   و اين در حالي است که شرکت SAMSUNG يا htc يا LG...          0
# 2530  و اين در حالي است که شرکت SAMSUNG يا htc يا LG...          0
# 5275                 و اپل هميشه برترين کيفيت رو داشته.          1
# 4151                 و اپل هميشه برترين کيفيت رو داشته.          0
# 2381           و به همین ترتیب در مدلهای Helmet و Surf.          0
# 1384           و به همین ترتیب در مدلهای Helmet و Surf.          0
# 2960        و ديگر مردم هم اين گوشي ها رو خريد نميکنن .         -1
# 4379        و ديگر مردم هم اين گوشي ها رو خريد نميکنن .          0
# 4476  و کسايي که وضع متوسطي داشتن با گوشي هاي اندروي...          0
# 808   و کسايي که وضع متوسطي داشتن با گوشي هاي اندروي...          0
# 213   واحد پردازش گرافيکي اين کنسول،  در فرکانس ۵۰۰ ...          0
# 3208  واحد پردازش گرافيکي اين کنسول،  در فرکانس ۵۰۰ ...          0
# 3510  واقعا از نظر ارسال سريع و کيفيت عالي بسته بندي...          2
# 502   واقعا از نظر ارسال سريع و کيفيت عالي بسته بندي...          2
# 967                                       واقعاً عاليه.          2
# 2717                                      واقعاً عاليه.          2
# 5251  ویندوز فون 8 به طور پیش فرض از مرورگر اینترنت ...          0
# 5453  ویندوز فون 8 به طور پیش فرض از مرورگر اینترنت ...          0
# 3873  پردازنده نوت2 چهار هسته اي هست ولي تو همه جا ث...          1
# 3314  پردازنده نوت2 چهار هسته اي هست ولي تو همه جا ث...          1
# 2815  پردازنده‌ي XBOX 360 با بهره‌گيري از فن‌آوري ۹۰...          0
# 2930  پردازنده‌ي XBOX 360 با بهره‌گيري از فن‌آوري ۹۰...          0
# 1341  پس حتی اگر کلاه ورزشی خاصی هم به سر نداشتید می...          1
# 4994  پس حتی اگر کلاه ورزشی خاصی هم به سر نداشتید می...          0
# 2446  چهارما:بزرگ شدن سنسور سيموس هيچ چيز برتري را د...         -1
# 3542  چهارما:بزرگ شدن سنسور سيموس هيچ چيز برتري را د...         -1
# 2633  چون ميدونن اين بازي رو که واسه ios ساختن 32 در...          0
# 1546  چون ميدونن اين بازي رو که واسه ios ساختن 32 در...          0
# 3103  چيپ‌ست Xenos به کار رفته در کنسول XBOX 360 روي...          0
# 3473  چيپ‌ست Xenos به کار رفته در کنسول XBOX 360 روي...          0
# 554                کدوم سيستم عامل آينده ي بهتري داره ؟          0
# 3229               کدوم سيستم عامل آينده ي بهتري داره ؟          0
# 5558      که اين فقط يک پاسخ دارد و آن ادبيات کاربريست!          0
# 1592      که اين فقط يک پاسخ دارد و آن ادبيات کاربريست!          0
# 5276  که باز هم فصل الختام اين داستان در يد تواناي ب...          0
# 1043  که باز هم فصل الختام اين داستان در يد تواناي ب...          0
# 3057  گاهی اوقات نیز می‌بینیم که برای فوکوس خودکار ب...          1
# 1990  گاهی اوقات نیز می‌بینیم که برای فوکوس خودکار ب...          1
# 3718                               گرافيک کدوم بيشتره ؟          0
# 1715                               گرافيک کدوم بيشتره ؟          0
# 1452  گرچه مهم هستن،  اما قضاوت نبايد صرفا بر اساس ا...          0
# 3544  گرچه مهم هستن،  اما قضاوت نبايد صرفا بر اساس ا...          0
# 1520  یک دوربین ورزشی اصولا باید از چه ویژگی هایی به...          0
# 3725  یک دوربین ورزشی اصولا باید از چه ویژگی هایی به...          0
# 807   یک راه دیگر استفاده از بند مخصوصی است که می تو...          0
# 4353  یک راه دیگر استفاده از بند مخصوصی است که می تو...          0
# 1134  یک مود عکاسی ماکرو برای فوکوس کردن و گرفتن عکس...          0
# 5461  یک مود عکاسی ماکرو برای فوکوس کردن و گرفتن عکس...          0
# 2710  یکی از راه های به همراه داشتن این دوربین،  بست...          2
# 4540  یکی از راه های به همراه داشتن این دوربین،  بست...          1
# 3413  یکی دیگر از تجهیزات عرضه شده برای این دوربین ک...          1
# 2808  یکی دیگر از تجهیزات عرضه شده برای این دوربین ک...          1
# 786   • کارت حافظه ـ وجود يک کارت حافظه‌ي ۶۴ مگابايت...          0
# 4672  • کارت حافظه ـ وجود يک کارت حافظه‌ي ۶۴ مگابايت...          0
# 422   • کنترل چند رسانه جهاني ـ اين وسيله در شنيدن م...          1
# 194   • کنترل چند رسانه جهاني ـ اين وسيله در شنيدن م...          1

# %% [markdown]
# As you can see, there are some duplicates in the comment column. Some of them have different sentiment values and some have the same sentiment.
# To prevent confusing our model we remove unvalid rows that have same comment with different sentiments and also will deduplicate the data rows

# %%
#remove duplicate rows
df = df.drop_duplicates(subset = None, keep='first')

#remove unvalid rows
df = df.drop_duplicates(subset='comment')

# %%
print_duplicate_by_column(df,'comment')
# Out:
# Empty DataFrame
# Columns: [comment, sentiment]
# Index: []

# %%
print('data information')
print(df.info(), '\n')
# Out:
# data information
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5359 entries, 0 to 5560
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   comment    5359 non-null   object
#  1   sentiment  5359 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 125.6+ KB
# None

# %% [markdown]
# # Clean Text

# %%
def cleanhtml(raw_html):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', raw_html)
    return cleantext


def CleanPersianText(text):
    _normalizer = hazm.Normalizer()
    #_lemmatizer = hazm.Lemmatizer()
    text = text.strip()
    text = cleanhtml(text)
    text = _normalizer.normalize(text)
    text = re.sub(r'[^a-zA-Z0-9آ-ی۰-۹ ]', ' ', text)
    # removing wierd patterns
    wierd_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u'\U00010000-\U0010ffff'
        u"\u200d"
        u"\u2640-\u2642"
        u"\u2600-\u2B55"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\u3030"
        u"\ufe0f"
        u"\u2069"
        u"\u2066"
        u"\u200c"
        u"\u2068"
        u"\u2067"
        "]+", flags=re.UNICODE)
    
    text = wierd_pattern.sub(r'', text)
    # removing extra spaces, hashtags
    text = re.sub("#", "", text)
    text = re.sub("\s+", " ", text)
    
    return text







'''

# turn a doc into clean tokens
def clean_doc(doc):
    doc = normalizer.normalize(doc) # Normalize document using Hazm Normalizer
    tokenized = word_tokenize(doc)  # Tokenize text
    tokens = []
    for t in tokenized:
      temp = t
      for p in puncs:
        temp = temp.replace(p, '')
      tokens.append(temp)
    # tokens = [w for w in tokens if not w in stop_set]    # Remove stop words
    tokens = [w for w in tokens if not len(w) <= 1]
    tokens = [w for w in tokens if not w.isdigit()]
    tokens = [lemmatizer.lemmatize(w) for w in tokens] # Lemmatize sentence words using Hazm Lemmatizer
    tokens = ' '.join(tokens)
    return tokens
'''
# Out:
# "\n\n# turn a doc into clean tokens\ndef clean_doc(doc):\n    doc = normalizer.normalize(doc) # Normalize document using Hazm Normalizer\n    tokenized = word_tokenize(doc)  # Tokenize text\n    tokens = []\n    for t in tokenized:\n      temp = t\n      for p in puncs:\n        temp = temp.replace(p, '')\n      tokens.append(temp)\n    # tokens = [w for w in tokens if not w in stop_set]    # Remove stop words\n    tokens = [w for w in tokens if not len(w) <= 1]\n    tokens = [w for w in tokens if not w.isdigit()]\n    tokens = [lemmatizer.lemmatize(w) for w in tokens] # Lemmatize sentence words using Hazm Lemmatizer\n    tokens = ' '.join(tokens)\n    return tokens\n"

# %%
df['comment'] = df['comment'].map(CleanPersianText)

# %% [markdown]
# # Comment Length

# %%
df['comment_len'] =df['comment'].apply(lambda comment: len(hazm.word_tokenize(comment)))
min_max_len = df['comment_len'].min(), df['comment_len'].max()
print(f'Min: {min_max_len[0]} \tMax: {min_max_len[1]}')
# Out:
# Min: 1 	Max: 335

# %%
df.sort_values(by='comment_len')
# Out:
#                                                 comment  sentiment  \
# 2325                                               مشکل          0
# 2661                                               سلام          0
# 1219                                               قیمت          0
# 436                                                عالی          2
# 1246                                              عالیه          2
# 2680                                              عالیه          2
# 5034                                         GearsOfWar          0
# 5091                                               سلام          0
# 5111                                               سلام          0
# 3583                                              ویدئو          0
# 2748                                               عالی          2
# 3572                                               سپاس          0
# 3553                                              محشره          0
# 299                                              عالیست          2
# 298                                                سلام          0
# 2000                                             تعطیله         -1
# 1462                                               سلام          0
# 3503                                               عالی          2
# 1987                                              عالیه          2
# 5220                                               سلام          0
# 269                                                سلام          0
# 1537                                               سلام          0
# 3364                                               سلام          0
# 3315                                               کوچک          1
# 1963                                               سلام          0
# 2268                                               داره          0
# 1628                                               همین          0
# 1944                                             متشکرم          0
# 3200                                             باسلام          0
# 3047                                              ممنون          0
# 4945                                               سلام          0
# 3046                                             باسلام          0
# 3856                                              عالیه          2
# 4926                                             ممنونم          0
# 2152                                            خوشدسته          1
# 784                                               میدهد          0
# 4442                                               سلام          0
# 834                                              باتشکر          0
# 2138                                              محشره          2
# 4351                                               سلام          0
# 4599                                               سلام          0
# 2540                                               سلام          0
# 4621                                             باسلام          0
# 2570                                               سلام          0
# 4649                                                اما          0
# 4300                                             بلوتوث          0
# 4289                                              عالیه          2
# 4675                                               همین          0
# 4242                                             باریکه          1
# 4683                                               سلام          0
# 642                                               معایب          0
# 637                                                سلام          0
# 995                                               باریک          1
# 4172                                               سلام          0
# 4166                                               سلام          0
# 1032                                             خریدمش          0
# 4755                                               عالی          2
# 584                                              ندوزید          0
# 2520                                             بگذریم          0
# 4048                                               سپاس          0
# 4793                                              عالیه          2
# 1092                                             بگذریم          0
# 4875                                               سلام          0
# 1187                                               خوبه          1
# 3033                                              عالیه          2
# 4463                                               سلام          0
# 3009                                             بگذریم          0
# 1823                                               سلام          0
# 5531                                               سلام          0
# 2215                                         موفق باشید          0
# 4973                                      دانلود موسیقی          0
# 2142                                          باطری خوب          1
# 3821                                      مرسی digikala          1
# 2419                                          قیمت بالا         -1
# 1813                                            با سلام          0
# 3673                                            با تشکر          0
# 5266                                        پیروز باشید          0
# 2480                                       پرینتر خوبیه          1
# 3323                                         داغ نمیکنه          1
# 4987                                         موفق باشین          0
# 1975                                            پر سرعت          1
# 2594                                         موفق باشید          0
# 4577                                          خیلی خوبه          2
# 2948                                             پر کار          1
# 5548                                          خیلی حیفه         -1
# 1409                                       دوربین خوبیه          1
# 2658                                          حرف نداره          1
# 3214                                        واقعا محشره          2
# 4438                                           شک نکنید          1
# 812                                          خیلی خفیفه          1
# 5345                                        واقعا محشره          2
# 3234                                         بدون اشکال          1
# 4169                                        سلام دوستان          0
# 612                                             با سلام          0
# 1647                                         خیلی عالیه          2
# 3878                                          منو عالیه          2
# 3273                                        فوق العادست          2
# 5488                                            با تشکر          0
# 3277                                        گوشی جالبیه          1
# 1193                                        سرعتشم خوبه          1
# 1955                                        بنظرم عالیه          2
# 2783                                         موفق باشید          0
# 1836                                             یا علی          0
# 3775                                         GPRS نداره         -1
# 4211                                           ارور داد          0
# 3764                                           فقط همین          0
# 2717                                        واقعا عالیه          2
# 1373                                           من دارمش          0
# 3543                                            فقط اپل          0
# 3627                                         داغ نمیکنه          1
# 1389                                            با تشکر          0
# 2343                                            با سلام          0
# 321                                           حرف نداره          2
# 2537                                         کارش بیسته          2
# 1397                                           عالی بود          2
# 664                                         دوربین عالی          2
# 2967                                       تصویرش عالیه          2
# 1421                                         دوربین خوب          1
# 5132                                       مخصوصا سفیدش          0
# 2866                                         گرافیک خوب          1
# 5121                                         قیمت عالیه          2
# 1828                                        سلام دوستان          0
# 4333                                        واقعا محشره          2
# 2982                                         موفق باشید          1
# 5061                                       میخوام بخرمش          0
# 2772                                        کیفیت عالیه          2
# 2565                                          مثل سونیP          0
# 857                                        باتریشم خوبه          1
# 967                                         واقعا عالیه          2
# 264                                          هنگ نمیکنه          1
# 3448                                    thanks digikala          0
# 1500                                           توجه کرد          0
# 513                                             با درود          0
# 961                                         مقایسه کردم          0
# 5225                                          سرعت عالی          2
# 4238                                         گوشی خوبیه          1
# 277                                          فوق العادس          2
# 2842                                         فوق العاده          2
# 5215                                         موفق باشید          0
# 5056                                            با سلام          0
# 689                                      ممنون DigiKala          1
# 3449                                         رم نمیخوره         -1
# 1682                                           صدای خوب          1
# 1610                                         موفق باشین          0
# 78                                           موفق باشین          1
# 4754                                         رمش پایینه         -1
# 4059                                        فوق العادست          2
# 4836                                          حرف نداره          2
# 5450                                            با سلام          0
# 4459                                          لذت ببرید          1
# 5410                                            با تشکر          0
# 1915                                            ۱ نداره          0
# 3090                                     ممنون digikala          1
# 755                                             با سپاس          0
# 4498                                           بی تردید          0
# 1748                                            با سلام          0
# 2302                                        واقعا عالیه          2
# 2149                                      کیبوردش عالیه          2
# 539                                         واقعا عالیه          2
# 4504                                          من خریدمش          1
# 804                                         واقعا محشره          2
# 743                                             با سلام          0
# 2507                                         موفق باشید          0
# 783                                          خیلی عالیه          2
# 4772                                            با سلام          0
# 600                                             با سپاس          0
# 4045                                            با سلام          0
# 4015                                         موفق باشید          0
# 3059                                         گوشی خوبیه          1
# 4477                                            با سلام          0
# 4505                                           بی صداست          1
# 580                                           پورت HDMI          0
# 4841                                          حرف نداره          1
# 1101                                         خیلی عالیه          2
# 2803                                              ۲۶۳ H          0
# 1120                                          ازش راضیم          1
# 3410                                   خریده خیلی خوبیه          2
# 3732                                    سرعت فوق العاده          2
# 3718                                 گرافیک کدوم بیشتره          0
# 1857                                   طراحی ۳۶۰ زیباست          1
# 4794                                     فوق العاده بود          2
# 4687                                        سلام به همه          0
# 5237                                   واقعا ارزش نداره         -1
# 3421                                    ممنون دیجی کالا          0
# 1272                                      سلام به همتون          0
# 795                                          زیبا و شیک          1
# 2048                                     مرسی دیجی کالا          1
# 1089                                      سید علی مومنی          0
# 2429                                      در حد انقلابی          1
# 106                                      سرعت خیلی خوبه          2
# 4375                             امیدوارم کمک کرده باشم          0
# 28                                      فوق العاده هستش          2
# 4989                                       کی راست میگه          0
# 2369                                     سلام به دوستان          0
# 3792                                        سلام به همه          0
# 5014                                     عالیه فقط همین          2
# 3070                                  فیلمش قابله قبوله          1
# 5213                                    کیفیت چاپش خوبه          1
# 3063                                   باسپاس امید بخشی          0
# 667                                      باتریش هم خوبه          1
# 1805                                     شگفت انگیزه نه          1
# 3590                                   عکسش تعریفی نیست         -1
# 576                                     متم امروز خریدم          0
# 2577                                    کیفیت ساختش تکه          1
# 5109                                   واسط کاربری زیبا          1
# 1913                                خلاصه دوربین جالبیه          1
# 5147                                       سرعت وای فای          0
# 771                                    تبلت بسیار خوبیه          2
# 778                                         دو پورت USB          0
# 1894                                     همش خیلی عالیه          2
# 920                                 قدرت پردازنده عالی٤          2
# 2133                                    من امروز خریدمش          0
# 4779                                     قصد دارم بخرمش          0
# 2088                                     و بدون استفاده         -1
# 4667                                         همه چی خوب          1
# 2022                                       به صرفه نیست         -1
# 2001                                  البته برای عاشقاش          0
# 4067                                      این یعنی تنزل         -1
# 4615                                   متشکرم دیجی کالا          0
# 5179                                        جدید هم هست          1
# 3509                                بهترین نسخه آندروید          2
# 875                                   کیفیت دوربین عالی          2
# 1775                                       خیلی خوب بود          2
# 388                                    واقعا معرکه هستش          2
# 3481                                       به صرفه میشه          1
# 17                                        همه چیش عالیه          2
# 1076                                        کاملا ضد خش          1
# 1496                                       همه چیش خوبه          1
# 2870                                قدرت پردازندش عالیه          2
# 2750                                   آداپتور برق بزرگ         -1
# 4201                                  عالیه خیلی زیباست          2
# 3589                                  باریکیش حرف نداره          0
# 2422                                   فوق العاده سریعه          2
# 2495                                     فوق العاده است          2
# 4163                                     از خریدم راضیم          1
# 1204                                    دوربین بی کیفیت         -2
# 2943                                         با عرض ادب          0
# 5304                                        ۲۶۴ را دارد          0
# 3999                                       و اما جزئیات          0
# 1618                                کیبوردش واقعا عالیه          2
# 2274                                      رنگ های متنوع          1
# 190                                        طراحی زیبا ۳          1
# 3847                                     تاچش حرف نداره          2
# 1620                                      دوربینش ۲۰است          0
# 1852                                 نوکیا دوباره برگشت          0
# 1715                                 گرافیک کدوم بیشتره          0
# 744                                   سلام دوستان عزیزم          0
# 230                                   دوسیم کارته عالیه          2
# 3986                                          فقط اچ پی          0
# 3150                                    ممنون دیجی کالا          0
# 4430                              xperia rayمنتظر شماست          0
# 4741                                    بالاخره تموم شد          0
# 20                                  دوربینش واقعا عالیه          2
# 3916                                    صفحه نمایش عالی          2
# 3262                                    ممنون دیجی کالا          0
# 1644                                       به صرفه نیست         -1
# 3255                                       سلام به همگی          0
# 3982                                     حتما یکی بخرید          0
# 732                                       خیلی عالی هست          2
# 3893                                     تاچ خوبی نداره         -1
# 3287                                       رنگ های زنده          1
# 2060                                       لپ تاپ خوبیه          1
# 4953                                      و خسته نباشید          0
# 2074                                  انصافآ تبلت خوبیه          1
# 4985                                     همه چیزش عالیه          2
# 3199                                     سلام به دوستان          0
# 4517                                      خیلی خوش دسته          2
# 1234                                  شفافیت صفحه نمایش          1
# 4199                            انصافا گوشی غولیههههههه          1
# 4811                                نوکیا داره برمیگرده          0
# 4013                                       البته که هست          0
# 114                                   باطریش خیلی ضعیفه         -2
# 2056                                     منظورم IOS هست          0
# 752                                  بهترین گوشی بازاره          2
# 4859                                    هنوزم شارژ داره          0
# 4527                                     من همینو میخرم          0
# 216                                   خودتون قضاوت کنید          0
# 3309                                   زیباییش کم نظیره          2
# 1672                                فقط ابعادش کوچیکتره          0
# 2416                                        چون خاص تره          1
# 448                                   com مراجعه نمایید          0
# 3842                                      ازش راضی هستم          1
# 4405                                     گوشیه بدی نیست          0
# 3300                                  باریکیش حرف نداره          1
# 3614                                 الان دوره S۲ گذشته          0
# 3895                        دوربین مکالمه ویدیویی نداره         -1
# 2500                           فیلم برداری تعریفی نداره         -1
# 2874                                   ۲۶۴ ثبت می گردند          0
# 5525                                  صفحه بزرگ ۴ اینچی          0
# 3958                                  با سلام خدمت همگی          0
# 2188                                  تو خریدش شک نکنید          0
# 2735                                پس فعلا دوستان عزیز          0
# 511                              صفحه نمایش فوق العاده٣          2
# 4096                                نسبت به قیمتش عالیه          2
# 2470                               خیلی خیلی خوبه عالیه          2
# 3922                             ۲۴۰ گیگابایت هارد دیسک          0
# 1115                              این دیگه بهترین تبلته          1
# 1387                                گارانتیش ۳ ساله بود          0
# 2466                                کاملا ازش راضی هستم          2
# 601                                        لاک جی پی اس          0
# 574                                    رفع مشکل وای فای          0
# 2732                             اصلا قصد تبلیغات ندارم          0
# 3617                                  هم تفریحه هم ورزش          0
# 4249                              با سلام خدمتان دوستان          0
# 5049                                 خدا کنه بیاد ایران          0
# 4917                                     ۱ طراحی چی بگم          0
# 3789                                  تو خریدش شک نکنید          1
# 1236                            مزایا دوربین فوق العاده          2
# 2329                            کیفیت تصاویرش خیلی خوبه          2
# 1252                              طراحی و ارگونومی عالی          2
# 4694                            شارژدهی باتری مناسب است          1
# 3011                                 نه دوربین های رقیب          0
# 4004                  امیدوارم استفاده کرده باشید بدرود          0
# 4743                                 موفق و پیروز باشید          1
# 4965                        امیدوارم استفاده کرده باشین          0
# 1280                                 تو حق انتخاب نداری          0
# 4689                                واقعا جای تاسف داره         -1
# 634                            گوشی واقعا استثنایی هستش          2
# 2525                             بله تعداد پیکسل بالاست          0
# 1100                                     پس چه باید کرد          0
# 4955                              واقعا دوربین عالی هست          2
# 2037                             باطریش راضی کننده نیست         -1
# 4027                             واقعا عالیه سیستم عالی          2
# 1114                                  فعلا که ازش راضیم          1
# 4919                            این گوشی را خواهیم خرید          0
# 1042                                برای خریدش شک نکنید          1
# 1859                                باید دید قیمتش چنده          0
# 3877                                 تکلیف PC دارها چیه          0
# 994                                 سرعت چاپش خیلی خوبه          2
# 2728                                   من ۲۰ روزه خریدم          0
# 386                                  علی الخصوص در صورت          0
# 1335                                پس محصول بد نمیسازد          0
# 2707                                 فقط مشکی موجود هست          0
# 3859                                  در خریدش شک نکنید          1
# 1319                               حافظه داخلی گوشی کمه         -1
# 2700                                   از همه نظر عالیه          2
# 3700                               صدای فوق العاده عالی          2
# 774                                سلام خدمت همه عزیزان          0
# 3963                                انتخاب خیلی سخت شده          0
# 5149                                 خیلی خوشگل و جذابه          2
# 1524                                  تو خریدش شک نکنید          0
# 2553                                 طراحیش هم حرفه ایه          1
# 703                               واقعا چیزی دیده نمیشه          0
# 3537                                  من هفته پیش خریدم          0
# 1541                                شفافه و تاچشم عالیه          2
# 2893                                 مثلا کانن یا نیکون          0
# 742                                  یه گوشیه تمام عیار          2
# 1875                             وضوع تصاویر یکم پایینه         -1
# 2542                                بسیار زیبا و کارامد          2
# 3528                               گوشی فوق العاده سریع          2
# 3101                          امکانات عالی صفحه براویا۴          2
# 5192                                گوشی فوق العاده ایه          2
# 3250                             بی صبرانه منتظر خریدشم          1
# 713                                  نسبتا سنگین و بزرگ         -1
# 1964                                  تنها عیبی که داره         -1
# 3493                                 محصولی دیگر از اپل          0
# 2250                                   این یه چیز دیگست          0
# 1584                                 وگرنه همه چیش خوبه          1
# 864                               برنامه خوریش هم عالیه          2
# 1822                           مخصوصا تبلتاش فوق العادن          2
# 1811                                  من این تبلتو دارم          0
# 4601                            صفحه نمایشش فوق العادست          2
# 4395                               امروز تبلت دستم رسید          0
# 2160                                 در کل پرینتر خوبیه          1
# 3464                                   من که خیلی راضیم          2
# 1935                                 نازکی و سبکی عالی٢          2
# 2559                                    نرم افزار iOS ۶          0
# 1743                          انتخاب با خودتونه خداحافظ          0
# 3286                               این گوشی واقعا عالیه          2
# 3585                                  خیلی خوب و زیباست          2
# 3017                            قابلیت جیوتگ برای ویدیو          1
# 2556                                 کلا ازش خیلی راضیم          2
# 5352                                 huawei ascend y۳۰۰          0
# 5245                                   یعنی gprs و edge          0
# 777                                  منم یه ماهه خریدمش          0
# 2832                                  شک نکنید حتا الان          0
# 249                                    و این یعنی دردسر         -1
# 1516                                    کاش full HD بود         -1
# 5456                              تو بازارم مشتری پسنده          0
# 779                                تو مجبوری انتخاب کنی          0
# 2365                                    به نظر خوب میاد          1
# 4639                               آینده از آن سامسونگه          0
# 3005                                  لپ تاپی بسیار خوب          2
# 3228                               ممنون میشم جواب بدید          0
# 1                                  سلام خیلی خوبه بخرین          2
# 5445                               گوشی بسیار عالی هستش          2
# 4521                               جواب این سوال منفیست          0
# 5360                                  یعنی شده مثل تبلت          0
# 5282                               خوشگل ترین فبلت جهان          2
# 1747                                 من ۱۵ شهریور خریدم          0
# 5424                                آدم میترسه خراب بشه         -1
# 780                                 این سنسور تقریبا ۱۹          0
# 1662                      از کیفیت بالاتری برخوردار اند          0
# 2648                              در کل xbox خیلی بهتره          2
# 2394                    همچنین کیفیت نامناسب صفحه نمایش         -1
# 161                               یه کم نگران کننده است          0
# 1146                               این لپ تاپ حرف نداره          2
# 1154                        اندازه این گوشی زیادی بزرگه         -1
# 3926                            گوشی خوبیه ولی S۲ بهتره          0
# 1413                             با فارسی هم مشکل نداره          1
# 1002                          گرافیکش که دیگه حرف نداره          2
# 3279                               با تشکر از دیجی کالا          1
# 1954                             از خریدش واقعا راضی ام          2
# 4935                             پس قرار نیست کم بیاورد          0
# 616                               از خوبیش هرچی بگم کمه          1
# 3869                              منم این گوشی رو خریدم          0
# 4931                             گوشی خوبی به نظر میرسه          1
# 5516                    همچنین به اندروید۴رو آپدیت میشه          0
# 3872                          من پیشنهادم Nokia ۶۰۳ هست          0
# 4898                    امیدوارم قیمت مناسبی داشته باشه          0
# 1183                             نسبت به قیمتش نمی ارزه         -1
# 4721                            آیا به نجوم علاقه دارید          0
# 2791                          این تبلت قابلیت GPRS داره          0
# 3248                           فارسی هم هیچ مشکلی نداره          1
# 5340                             جواب این سوال مثبت است          1
# 487                         کیفیت کار این پرینتر عالیست          2
# 3903                            به راحتی امکان پذیر است          0
# 4880                             اما این مشکلش خیلی بده         -2
# 3906                               سبکه و فوق العاده اس          2
# 4423                           این دوربین ساخت چین هستش          0
# 610                                   به غیر از dvd rom          0
# 2616                              نسبت به قیمتش خوب است          1
# 4734                              از همه نظر هارد خوبیه          1
# 5417                      effectهای مختلف نقاشی آبرنگ و          0
# 4130                             من خریدم خیلی هم راضیم          2
# 1030                                 با بهره گیری از مک          0
# 2370                       من امروز سفارش اینترنتی دادم          0
# 3087                              فیلم از اکس باکس لایو          0
# 4456                             من که واقعا پشیمون شدم         -1
# 1088                          من دوربین خریدم راضی هستم          1
# 4024                           باورم نمیشه فوق العاده س          2
# 117                            عدم اجرای فیلم های بلوری          0
# 4030                           البته باید باهاش کار کرد          0
# 2637                       دوربین های ژاپنی همشون عالین          2
# 2307                          البته وبکمش واقعا HD نیست         -1
# 4782                            ممنون که تا آخرش خوندین          0
# 4075                       بازی آنلاین عالی با XboxLive          2
# 4774                           پدفون ۲ دوربین خوبی داره          1
# 3010                            فبلت خوبی همه چیزش کامل          1
# 3025                      تنها برتری xbox قیمت بازیهاشه          1
# 4762                            ۲۶۴ RealVideo ۸ SDP WMV          0
# 4487                            رنگ مشکی کاملا عمیق است          1
# 29                               اپل رو واقعا دوست دارم          1
# 5416                            باسپاس از شما امید بخشی          0
# 802                        کیفتش super amoled plus نیست         -1
# 154                         کیفیت ساخت نیز بسیار بالاست          2
# 5484                            اونا یکم تو کیفیت بهترن          1
# 1939                               همشون شبیه f۵۰۰ هستن          0
# 2201                                   اما در مورد Y۳۰۰          0
# 2498                        با اطمینان میگم این بهترینه          1
# 740                             گوشی خوبی نسبت به قیمتش          1
# 5313                            عدم وجود قابلیت full HD         -1
# 2385                               به نظر من خیلی عالیه          2
# 798                               آخر به کجا کشیده میشه          0
# 521                            از nokia belle خوشم اومد          1
# 1704                                 با بهره گیری از مک          0
# 4848                              از صداش هم خوشم نیومد         -1
# 2103                            ps۳ واقعا فوق العاده اس          2
# 133                               روی هم رفته خوبه خوبه          1
# 3148                             تا چه حد موفق بوده اید          0
# 5553                            رنگ مشکی کاملا عمیق است          0
# 3147                         اصلا از سامسونگ خوشم نمیاد         -1
# 1110                            باتری i۹۱۰۰ قویتر میکرد          0
# 137                           ضمنا جای بسیار کمی میگیره          2
# 4415                             پاسخ این سوال مثبت است          1
# 1049                             از خریدی که کردم راضیم          1
# 3846                          این پرینتر فوق العاده است          2
# 701                           سامسونگ یعنی آینده در حال          0
# 5514                          دوربین خیلی خیلی خوبی هست          2
# 2996                             پاسخ این سوال مثبت است          1
# 4233                          از اصلاح کردن قیمت ممنونم          1
# 5230                     محدودیت بزرگترین کابوس بشر است          0
# 2438                         برین یه گوشی معمولی بگیرین          0
# 1866                               و خیلی بازی های دیگه          0
# 1318                               با تشکر از دیجی کالا          0
# 1506                              در خریدش نباید شک کرد          0
# 1507                         از نظر قیافه واقعا شاهکاره          1
# 5232                        بهترین گوشی حال حاضر دنیاست          2
# 2567                             من واقعا ازش راضی هستم          2
# 1391                          حافظه داخلی گوشی ۱٫۴ گیگه          0
# 5165                               آیا یک روز کافی نیست          0
# 4091                             ۳۶۰ مگ حافظه آزاد داره          0
# 1521                          دوربینش هم که فوق العادست          2
# 3742                      کلا بهتره هر دوشو داشته باشید          0
# 3768                                 اما نه به طور کامل         -1
# 1430                               در کل مرسی دیجی کالا          1
# 39                               از دیجی کالا هم ممنونم          0
# 312                           اصلا طرح هاشون متنوع نیست         -1
# 4628                              CPU این گوشی ۱Ghz است          0
# 3635                       دوربینشم متوسطه ولی بدم نیست          1
# 3539                       تلویزیون خوبیه نسبت به قیمتش          1
# 2729                            مرسی از دیجی کالای عزیز          0
# 3554                           سرعت و گرافیک بسیار عالی          2
# 4634                                 با یک کاور حل میشه          1
# 2702                            بهمراه دسته های سیم دار          0
# 3535                           ممنونم که تا آخرش خوندین          0
# 302                               گوشی عالی و خوش دستیه          2
# 1350                      مودهای عکاسی خیلی متنوع هستند          2
# 14                             توی قیمت بهترین گوشی هست          1
# 2024                             من این حرفو قبول ندارم          0
# 956                                اگه که بیاد من میخرم          0
# 2541                          امکانات جانبی در حد متوسط          0
# 2248                             پلاس هم که مشکلی نداره          1
# 2179                          از لحاظ باتری واقعا عالیه          2
# 1523                           در نهایت انتخاب با شماست          0
# 5233                              زود باشید تا دیر نشده          0
# 5007                           همین که ایسوس خودش خیلیه          0
# 4192                            تنها مشکلش داغی فنش هست         -1
# 2161                            ممنون که تا آخرش خوندین          0
# 3594                         یکی از بهترین های سامسونگه          2
# 209                              این یکی از بهترین هاست          2
# 3833                              من که واقعا ازش راضیم          2
# 4961                             در نوع خودش تبلت خوبیه          1
# 4406                          کیفیت ساخت خیلی خوبی داره          2
# 1221                      هیچ تلوزیونی مثل پلاسما نمیشه          1
# 3298                             منم میخوام از این بخرم          0
# 3288                            سرعت و عملکرد خوبی دارد          1
# 199                             حیف که سیم کارت نمیخوره         -1
# 992                        البته باید منتظر قیمتش باشیم          0
# 5128                       گوشی بسیار مناسب و قدرتمندیه          2
# 4553                              من که خیلی دوستش دارم          2
# 2486                           دوربین واقعا عالی ای هست          2
# 4298                                 در کل من ازش راضیم          1
# 5131                                که از کجا فعال میشه          0
# 5501                                  خیلی خر تو خر شده         -1
# 210                           باتشکر از وقتی که گذاشتید          0
# 3600                             این هم ویژگی جالبی است          1
# 1556                      روشنایی صفحه نمایش نیز عالیست          2
# 3305                            صفحه نمایش خوبی هم داره          1
# 4384                        پردازنده خوب با سرعت مناسب۶          1
# 2852                             رنگ سفیدش باز بهتر بود          0
# 3807                           به کدام ورزش علاقه مندید          0
# 4703                              خیلی هم ازش راضی هستم          2
# 4640                             شیره PS۳ همه دروغ میگن         -1
# 3404                               من که خیلی خوشم اومد          2
# 242                 امیدوارم تو انتخابتون کمک کرده باشم          0
# 57                       محدودیت بزرگترین کابوس بشر است          0
# 5276                             بدنه ی دوربین محکم است          1
# 3581                               دوربین hd و سه بعدی۵          0
# 5144                               البته یه بدی هم داره         -1
# 4382                          من منتظرم بیاد یکی میخوام          0
# 4489                        سخت از مواضع خود دفاع میکنه          0
# 4326                   تلویزیون بی نظیریه ولی داغ میکنه          1
# 790                       سلام من همین امروز بدستم رسید          0
# 673                          خدا رحمت کنه استیو جابز رو          0
# 4643                     بدیاش اینه که فلشش خودکار نیست         -1
# 4316                    من ۲روزه خریدمش واقعا حرف نداره          1
# 2879                   خیلی راحت فوکوس خودکار عمل میکنه          2
# 661                      بهتر از این نمیتونید پیدا کنید          1
# 4103                             رو به راحتی باز می کنه          1
# 662                         این یک رکورد شگفت انگیز است          1
# 2177                      همه با نقاط قوتش آشنایی دارین          0
# 2555               فوکوس اتوماتیک بسیار عالی عمل میکنید          2
# 4132                           و فوق العاده از آن راضیم          2
# 928                        من امروز این گوشی بدستم رسید          0
# 4547                   گول قیمت play station۳ را نخورید          0
# 2561                       با عرض سلام خدمت دوستان عزیز          0
# 4539                            فقط بدنه اش خش پذیر است         -1
# 4178                                ۵ اینچ ال سی دی است          0
# 2156                            این لپ تاپ بر طرف میکنه          1
# 985                            من که خیلی ازش راضی بودم          2
# 4174                             در کل به قیمتش می ارزه          1
# 4706                      Apple iPhone ۵ یه گوشی هوشمند          0
# 843                      تبلت خوبیه و باهاش مشکلی ندارم          1
# 4532                         همورو به راحتی اجرا می کنه          1
# 2563                  بهتون پیشنهاد میکنم که حتما بخرید          0
# 4735                   از مشخصاتش معلومه که گوشیه خوبیه          1
# 970                           عالی عالی عالی از همه نظر          2
# 4688                        احتمالا تا ۲ ماه آینده بخرم          0
# 2886                          ما که همه جوره راضی هستیم          1
# 866                          سرعت خیلی خوبه و کم نمیاره          2
# 748                        در ادامه بیشتر توضیح می دهیم          0
# 2568                خیلی دوربین خوبیه کیفیت عکساش عالیه          2
# 4747                           من ۴ ماهه این گوشیو دارم          0
# 938                       و اینو بیشتر از ایفون پسندیدم          0
# 2619                        من عاشق این گوشیم نقص نداره          1
# 654                        امیدوارم که هر چه زودتر بیاد          1
# 4502                  از کمپانی اپل انتظار بیشتری داشتم          0
# 4290                           کیفیت صدا و پخش اون خوبه          1
# 4413                            در کل لپ تاپ خیلی خوبیه          0
# 3016                      کار اصلی تبلت چیزهای دیگه هست          0
# 2922                     ایا دو برابر کیفیت دوربین داره          0
# 3569                        این یک رکورد شگفت انگیز است          1
# 176                             همه چیزش هم در حد خوبیه          1
# 1426                                   به نظر من i۹۱۰۰g          0
# 3573                          فقط میخام تجربه ام رو بگم          0
# 5336                            من این گوشی رو تست کردم          0
# 3578                      نسبت به ۴s تغییرات مهمی نکرده          0
# 327                        رم قابل قبول و دیگر امکاناتش          1
# 5503                        امروز این گوشی به دستم رسید          0
# 3247                     عالیه دیجی کالا کارت حرف نداره          2
# 3244                       شکل ظاهریش هم که خیلی زیباست          2
# 5342                 امکاناتش نسبت به قیمتش فوق العادست          2
# 2236                       فقط میتونم بگم فوق العاده ست          2
# 5119                         باید lcd رو خاموش روشن کنم          0
# 5327                          ۲۶۴ را نیز دارد که عالیست          2
# 345                      نسبت به پولش واقعا کارایی داره          1
# 3622                     فیلم برداری قابل قبولی هم داره          1
# 5084                         من حدود دو ماهه اینو خریدم          0
# 1378                    من از بازار موبایل اصفهان گرفتم          0
# 153                         گوشی مناسب خوب و کارایی است          1
# 369                          حتی از زیبایی هم حرف نداره          2
# 3202                         ای کاش رادیو هم داشته باشه          0
# 370               بهترین پشتیبانی در تبلت های آندرویدی۲          2
# 372                     آخه نانو سیمکارتو از کجا بیاریم          0
# 373                        سرعت گوشی هم واقعا رفته بالا          1
# 3183               بهترین تجربه رو با ایفون۵داشته باشین          0
# 1698                   دوربینی مناسب کار های معمولی است          1
# 3154                          پیشنهاد ویژه ی دی جی کالا          0
# 3371                          مجهز به یک گیگابایت رم ۱۱          1
# 350                    البته شارژدهی نسبتا خوبی می باشد          1
# 131                      بخصوص اینکه U۳ هم ساپورت میکنه          1
# 180                           در خرید این گوشی شک نکنید          0
# 3541                           گوشی عالی بود عالی تر شد          2
# 1569                          ۵ عدم وجود یک قلم کاربردی         -1
# 2259                      اگه پول دستم بیاد حتما میخرمش          1
# 238                          و برنامه و بازی خوری مناسب          1
# 3003                         ولی در کل ارزش خریدشو داره          1
# 3415                          فقط در یک جمله میتونم بگم          0
# 5558                 برخلاف تمام پیش بینیهای اغراق آمیز          0
# 1517               بهترین تجربه رو با ایفون۵داشته باشین          1
# 2771                   اگه میخواین بخرینش اصلا شک نکنید          2
# 2253                           هم شیکه هم کار راه انداز          1
# 3333                      چه اندرویدی و چه غیر اندرویدی          0
# 5267                    سرعت به صورت چشمگیری پایین میاد         -1
# 1985                 معایب نوکیا ۵۰۰ خیلی آزاردهنده است         -2
# 273                          من این گوشی رو امروز خریدم          0
# 5168                 خوشحال میشم نظرهای متفاوت رو ببینم          0
# 1497                          صداش هم یک مقدار ضعیف هست         -1
# 5283                           من این تبلتو ۲ ماه داشتم          0
# 5294                      برای خرید این پرینتر شک نکنید          1
# 1485                      لانچر که عوض میشه مشکلی نداره          1
# 5302                           نداشتن رابط یو اس بی هست         -1
# 1614                             کلا بگم یک همه فن حریف          1
# 1992              Event Selection نیز کارآیی جالبی دارد          1
# 1957                             خوب این جا چی می بینیم          0
# 1619                بزرگترین مشکلش نداشتن سیم کارت هستش         -1
# 1629                      گرونتر هم باشه ارزش خرید داره          1
# 2846                      با توجه به قیمتش پرینتر خوبیه          1
# 2311                          قصد اصلی من برای بازی بود          0
# 5177                         به همین جهت هنوز ذکر نکردن          0
# 2752                       کیفیت چاپ اولیه که حرف نداره          2
# 3480                         ویژگی های برجسته نکسوس ۷ ۱          0
# 3138                            من که خریدم ازش راضی ام          1
# 228                           از هر نظر ۱۰۰ درصد عالیست          2
# 3110                         دیگه چی میخواین از یه گوشی          0
# 3879                         هنوز تا این تاریخ روت نشده          0
# 3884                               سبک و زیبا و پر قدرت          1
# 2209                    دوربین خوب و فوق العاده اقتصادی          2
# 490                       سامسونگ و ال جی همیشه بهترینن          2
# 3049                     اپل همیشه بهترین کیفیت رو داره          1
# 1150                     قابلیت اتصال بند به پشت دستگاه          0
# 2070                        البته تحول در طراحی های خود          0
# 1142                            سبک و زیبا فقط ۱۰۰ گرم۳          1
# 3946                           هر چند این گوشیش بد نیست          0
# 3948                       با سلام خدمت شما دوستان عزیز          0
# 2647                  خوشحال شدم از سایت خوبتون خداحافظ          0
# 86                  فقط نتونستم Fingerprint رو فعال کنم          0
# 1810                      اگه زودتر میومد خیلی بهتر بود          0
# 2079                         این گوگل داره چی کار میکنه          0
# 526                         گوشی واقعا خوش دست و سریعیه          2
# 3038                    چون دوتاشونم چندین بار تست کردم          0
# 2643                      سبک ابعاد خیلی عالی سرعت بالا          2
# 4823                     خرید اون خیلی سخته بخاطر قیمتش         -1
# 2197          امکانات بسیار عالی itunes icloud imesaage          2
# 4819                     کیفیت دسکتاپ چنگی به دل نمیزنه         -1
# 4816                       ایا دو برابر کیفیت صفحه داره          0
# 1791                       قابلیت پخش ویدئو در پس زمینه          0
# 2511                       اگه کسی میدونه حتما خبرم کنه          0
# 2923                   دوربینشم که جایی برای حرف نذاشته          0
# 1063                       عکاسی و فیلم برداریش هم خوبه          1
# 4076                عکسهایی که باهاش میگیرم فوق العادست          2
# 5469                         کیفیت بدنش متوسط رو به خوب          1
# 474                           آن را هم خیلی دوست داشتیم          0
# 1189                              و در آخر من عاشقش شدم          2
# 2932                     نقاط ضعف سیستم منو های نامناسب         -1
# 3786                         یک مشکل داره اون نم باطریش         -1
# 411                       به نظرم برای خرید انتخاب کنید          0
# 1925                        این لنز فوق العاده سریع است          2
# 4958                             یک پک خوب و ارزان قیمت          1
# 2814                  با بیمه و گارانتی هماهنگ متاسفانه         -1
# 3094                 دیگه ببینین iPhone۵ چی میخواد باشه          0
# 3734                  البته نبود فلاش واسه دوربینش ضعفه         -1
# 2040                   عاشق پیشنهاد های ویژه هستم ممنون          1
# ...
# 4881           35
# 3242           35
# 2920           35
# 4321           35
# 4082           35
# 5050           35
# 3237           35
# 3855           35
# 2139           35
# 4964           36
# 5203           36
# 5339           36
# 4912           36
# 275            36
# 541            36
# 203            36
# 443            36
# 3943           36
# 745            36
# 856            36
# 1790           36
# 1330           36
# 4159           36
# 707            36
# 2983           36
# 2964           36
# 2550           36
# 4120           36
# 981            36
# 4658           36
# 2836           36
# 2110           36
# 3424           36
# 738            36
# 2023           36
# 3490           36
# 4588           36
# 3941           36
# 1436           36
# 1382           36
# 622            36
# 1816           36
# 4709           36
# 1711           36
# 3127           36
# 1285           36
# 3836           36
# 1736           36
# 595            36
# 2267           36
# 1742           36
# 4730           36
# 4574           36
# 3207           36
# 3849           36
# 4219           36
# 3081           36
# 2431           36
# 1021           37
# 4856           37
# 4546           37
# 2709           37
# 3227           37
# 202            37
# 5273           37
# 172            37
# 2028           37
# 1468           37
# 4018           37
# 1719           37
# 4468           37
# 4396           37
# 5407           37
# 1530           37
# 191            37
# 1263           37
# 1778           37
# 3387           37
# 1883           37
# 3354           37
# 3289           37
# 1681           37
# 4287           37
# 1903           37
# 3785           37
# 1446           37
# 1209           37
# 3605           37
# 2185           37
# 1313           37
# 545            37
# 684            37
# 1297           37
# 3751           37
# 3720           37
# 657            37
# 5162           37
# 2632           37
# 1431           37
# 4840           37
# 4630           37
# 4605           37
# 5069           37
# 860            38
# 1329           38
# 239            38
# 3688           38
# 1015           38
# 3020           38
# 2531           38
# 3270           38
# 1819           38
# 848            38
# 437            38
# 4378           38
# 1632           38
# 3035           38
# 485            38
# 711            38
# 4702           38
# 1273           38
# 4944           38
# 932            38
# 4245           38
# 2349           38
# 3722           38
# 3116           38
# 4760           38
# 3196           38
# 2280           38
# 5072           38
# 1312           38
# 2446           38
# 1774           38
# 2237           38
# 3218           38
# 613            38
# 3651           38
# 3896           38
# 5411           38
# 3413           38
# 1997           38
# 5202           38
# 1498           38
# 4247           38
# 4520           38
# 2603           38
# 2101           38
# 414            38
# 3582           38
# 2026           38
# 4597           38
# 4017           38
# 1103           38
# 3542           38
# 1491           38
# 2808           38
# 5413           38
# 3144           38
# 5218           38
# 824            38
# 4105           38
# 385            38
# 1533           38
# 1877           38
# 1376           38
# 3647           38
# 2931           38
# 3911           38
# 2822           38
# 5482           38
# 1887           38
# 1336           39
# 955            39
# 3664           39
# 391            39
# 4162           39
# 4224           39
# 5051           39
# 454            39
# 3426           39
# 3412           39
# 4215           39
# 5001           39
# 4981           39
# 3406           39
# 3365           39
# 3473           39
# 3103           39
# 4256           39
# 1919           39
# 5428           39
# 5389           39
# 811            39
# 75             39
# 2102           39
# 496            39
# 4645           39
# 4902           39
# 2999           39
# 2762           39
# 4358           39
# 2533           39
# 4692           39
# 5414           39
# 884            39
# 626            39
# 5510           39
# 1781           39
# 3111           39
# 2407           39
# 5534           39
# 552            39
# 3975           40
# 3976           40
# 2675           40
# 3675           40
# 2027           40
# 98             40
# 2718           40
# 2376           40
# 5543           40
# 1504           40
# 3790           40
# 3969           40
# 2626           40
# 3601           40
# 1153           40
# 2265           40
# 3608           40
# 5521           40
# 3623           40
# 3848           40
# 2119           40
# 2120           40
# 5053           40
# 4679           40
# 2164           40
# 611            40
# 2535           40
# 324            40
# 540            40
# 4769           40
# 2810           40
# 2921           40
# 1973           40
# 2985           40
# 4380           40
# 3337           40
# 853            40
# 3041           40
# 3053           40
# 5323           40
# 1754           40
# 3292           40
# 4092           40
# 206            40
# 1538           40
# 5397           40
# 4126           41
# 1241           41
# 2598           41
# 4766           41
# 1642           41
# 3728           41
# 3899           41
# 668            41
# 5307           41
# 4171           41
# 1786           41
# 1718           41
# 862            41
# 1673           41
# 4123           41
# 3839           41
# 3841           41
# 885            41
# 3195           41
# 38             41
# 5043           41
# 5373           41
# 3422           41
# 1994           41
# 2749           41
# 101            41
# 1039           41
# 3146           41
# 4016           41
# 3596           41
# 716            41
# 2055           41
# 132            41
# 2706           41
# 2651           41
# 2660           41
# 3352           41
# 5160           41
# 1122           41
# 4603           41
# 286            42
# 5530           42
# 5296           42
# 3176           42
# 3172           42
# 1617           42
# 2295           42
# 2338           42
# 5156           42
# 2746           42
# 1486           42
# 3258           42
# 1806           42
# 2685           42
# 3707           42
# 3320           42
# 5186           42
# 1638           42
# 42             42
# 1465           42
# 5175           42
# 2053           42
# 1439           42
# 3241           42
# 2859           42
# 2863           42
# 3555           42
# 4878           42
# 3923           42
# 4416           42
# 4280           42
# 466            42
# 4646           42
# 951            42
# 4494           42
# 4590           42
# 3805           42
# 4143           42
# 842            42
# 4137           42
# 734            42
# 1031           42
# 4729           42
# 4585           42
# 948            43
# 5126           43
# 195            43
# 581            43
# 1044           43
# 3513           43
# 472            43
# 84             43
# 2406           43
# 3558           43
# 3566           43
# 2840           43
# 3026           43
# 1035           43
# 1851           43
# 23             43
# 835            43
# 303            43
# 2889           44
# 1428           44
# 4930           44
# 1867           44
# 3914           44
# 2971           44
# 4368           44
# 2332           44
# 4907           44
# 1363           44
# 3425           44
# 3433           44
# 4549           44
# 3442           44
# 4222           44
# 1968           44
# 966            44
# 2227           44
# 3898           44
# 1942           44
# 1920           44
# 2364           44
# 3126           44
# 2839           44
# 413            45
# 3497           45
# 547            45
# 5199           45
# 3106           45
# 1148           45
# 1528           45
# 4037           45
# 2264           45
# 2779           45
# 3366           45
# 770            45
# 2834           45
# 4496           45
# 2845           45
# 353            45
# 5379           45
# 3642           45
# 2340           45
# 2328           45
# 1868           45
# 1946           46
# 3702           46
# 5185           46
# 4257           46
# 3392           46
# 566            46
# 1390           46
# 4849           46
# 1873           46
# 4122           46
# 633            46
# 1635           46
# 4528           46
# 488            46
# 1729           46
# 4491           47
# 753            47
# 2688           47
# 2230           47
# 5210           47
# 4145           47
# 3325           47
# 3743           47
# 4089           47
# 218            47
# 2058           47
# 5515           47
# 2378           47
# 817            47
# 909            47
# 2974           47
# 1344           47
# 2811           47
# 3157           47
# 3143           47
# 113            48
# 3329           48
# 80             48
# 4911           48
# 2524           48
# 4337           48
# 4072           48
# 5377           48
# 5475           48
# 1951           48
# 2198           48
# 1349           48
# 4152           48
# 449            48
# 791            48
# 5293           48
# 761            48
# 1708           48
# 3864           48
# 193            49
# 823            49
# 4876           49
# 1653           49
# 4695           49
# 3045           49
# 931            49
# 2924           49
# 2483           49
# 1424           49
# 1102           49
# 1138           49
# 3676           49
# 3643           49
# 3754           49
# 3230           50
# 152            50
# 4566           50
# 1928           50
# 776            50
# 1075           50
# 3997           50
# 5312           50
# 5183           50
# 4759           50
# 3019           50
# 2402           50
# 1986           50
# 4347           50
# 3383           50
# 4583           50
# 1238           50
# 4537           50
# 2211           51
# 3826           51
# 2136           51
# 2384           51
# 1890           51
# 592            51
# 926            51
# 575            51
# 3467           51
# 4879           51
# 2855           51
# 3042           51
# 332            51
# 4355           51
# 2794           51
# 1299           51
# 3512           51
# 4063           51
# 3913           51
# 2904           51
# 244            51
# 5238           51
# 359            51
# 4844           52
# 3980           52
# 3674           52
# 5388           52
# 1665           52
# 5195           52
# 2928           52
# 2075           52
# 619            52
# 869            52
# 2611           52
# 4225           52
# 4483           52
# 4626           53
# 3380           53
# 2395           53
# 4138           53
# 1442           53
# 1372           53
# 4305           53
# 685            53
# 4569           53
# 2333           53
# 4761           53
# 221            53
# 4470           53
# 5094           53
# 5415           53
# 650            53
# 531            54
# 2692           54
# 2737           54
# 3892           54
# 792            54
# 5316           54
# 507            54
# 4186           54
# 4503           54
# 3131           54
# 3574           54
# 4276           54
# 2083           54
# 4731           54
# 2497           55
# 52             55
# 2372           55
# 882            55
# 3188           55
# 1717           55
# 4411           56
# 585            56
# 2720           56
# 4124           56
# 2191           56
# 1340           56
# 2034           56
# 1070           56
# 468            56
# 825            56
# 3798           56
# 4209           56
# 3456           56
# 4892           56
# 2401           56
# 2987           57
# 827            57
# 3361           57
# 5277           57
# 3322           57
# 596            57
# 93             57
# 37             57
# 1706           57
# 2334           57
# 1157           57
# 3862           57
# 4871           57
# 1190           57
# 2355           57
# 3644           57
# 331            58
# 2739           58
# 2062           58
# 4578           58
# 1878           58
# 1905           58
# 1809           58
# 3472           58
# 569            58
# 1471           58
# 1797           58
# 1012           58
# 2997           58
# 284            58
# 681            59
# 5337           59
# 143            59
# 3474           59
# 358            59
# 1369           59
# 2036           59
# 5151           60
# 4884           60
# 3166           60
# 1403           60
# 5367           60
# 1940           60
# 623            61
# 3814           61
# 1759           62
# 231            62
# 3591           62
# 2444           62
# 1425           62
# 1056           62
# 2742           62
# 2736           63
# 1087           63
# 1326           63
# 2662           63
# 21             63
# 4009           63
# 2667           63
# 1402           63
# 1854           63
# 5153           63
# 272            64
# 2153           64
# 427            64
# 4479           64
# 1149           64
# 1773           64
# 3691           64
# 4905           64
# 3978           65
# 1164           65
# 219            65
# 295            65
# 1207           65
# 2841           65
# 2683           65
# 2195           65
# 5308           65
# 1304           65
# 1071           66
# 5083           66
# 5024           66
# 3197           67
# 2043           67
# 2196           67
# 3044           67
# 625            67
# 5329           67
# 1601           68
# 3443           68
# 297            68
# 187            68
# 1084           68
# 147            68
# 3466           69
# 2050           69
# 3007           69
# 9              69
# 4254           69
# 1194           70
# 4883           70
# 2321           71
# 1064           71
# 196            72
# 3115           72
# 2200           72
# 5519           72
# 2410           72
# 4183           72
# 4947           72
# 4789           72
# 330            72
# 4397           73
# 4815           73
# 2228           73
# 3465           73
# 1567           73
# 2449           74
# 1163           74
# 963            74
# 2214           74
# 64             75
# 1245           75
# 3598           75
# 1683           75
# 3206           76
# 2506           76
# 2039           77
# 4003           77
# 55             79
# 876            79
# 185            79
# 5547           80
# 2143           80
# 4451           81
# 2722           81
# 2076           81
# 1068           82
# 3529           83
# 1399           83
# 4571           83
# 1160           83
# 4814           84
# 1762           85
# 3886           85
# 1817           86
# 3940           86
# 1412           87
# 4              87
# 832            87
# 4329           88
# 873            89
# 2885           89
# 3791           90
# 4928           92
# 4010           92
# 4534           92
# 178            94
# 1175           94
# 546            94
# 2219           95
# 1686           95
# 4373           95
# 428            96
# 4350           96
# 3891           97
# 3936           97
# 1882           97
# 2279           98
# 2005           99
# 4804          100
# 1147          101
# 1679          101
# 211           102
# 921           105
# 4625          105
# 4064          105
# 4711          109
# 3156          109
# 3677          111
# 5455          111
# 4049          116
# 82            117
# 4715          119
# 1514          121
# 2978          122
# 1079          124
# 4995          125
# 4322          125
# 3120          128
# 4650          130
# 5158          132
# 1029          135
# 5120          136
# 3194          136
# 215           137
# 1294          141
# 3713          143
# 1037          150
# 4548          160
# 4636          163
# 361           167
# 679           169
# 978           170
# 3854          173
# 1674          192
# 2409          196
# 434           218
# 61            219
# 5385          219
# 4356          237
# 3685          252
# 3777          268
# 3560          269
# 5289          274
# 4927          275
# 5536          276
# 4764          301
# 1191          335

# %%
# remove comments with the length of fewer than 1 word 
df['comment_len'] = df['comment_len'].apply(lambda len_t: len_t if 0 < len_t  else None)
df = df.dropna(subset=['comment_len'])
df = df.reset_index(drop=True)

# %% [markdown]
# # Stats

# %%
def show_comment_length_distribution(df):
    fig = go.Figure()

    fig.add_trace(go.Histogram(
        x=df['comment_len']
    ))

    fig.update_layout(
        title_text='Comment lenght distribution',
        xaxis_title_text='Word Count',
        yaxis_title_text='Frequency',
        bargap=0.2,
        bargroupgap=0.2)

    fig.show()
show_comment_length_distribution(df)
# Out:
# <div>                            <div id="84318f22-dec2-4665-8a25-a82b13d5b93d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84318f22-dec2-4665-8a25-a82b13d5b93d")) {                    Plotly.newPlot(                        "84318f22-dec2-4665-8a25-a82b13d5b93d",                        [{"type": "histogram", "x": [16, 4, 30, 16, 87, 7, 9, 15, 12, 69, 33, 28, 19, 30, 5, 35, 28, 3, 13, 18, 3, 63, 14, 43, 20, 9, 13, 17, 3, 5, 17, 22, 11, 27, 13, 22, 19, 57, 41, 5, 14, 25, 42, 17, 22, 12, 14, 23, 12, 32, 26, 13, 55, 14, 29, 79, 10, 5, 25, 26, 33, 219, 27, 25, 75, 22, 35, 29, 7, 28, 19, 26, 10, 22, 25, 39, 14, 16, 2, 15, 48, 22, 117, 7, 43, 12, 6, 14, 16, 25, 29, 19, 25, 57, 20, 6, 8, 20, 40, 9, 18, 41, 10, 7, 29, 34, 3, 29, 16, 15, 11, 15, 16, 48, 3, 7, 22, 5, 17, 8, 26, 29, 21, 24, 8, 9, 21, 13, 29, 16, 14, 6, 41, 5, 26, 25, 14, 5, 28, 14, 17, 35, 16, 59, 9, 17, 15, 68, 27, 12, 21, 11, 50, 6, 5, 16, 16, 18, 12, 19, 15, 5, 11, 29, 20, 11, 29, 10, 19, 31, 33, 28, 37, 33, 11, 27, 6, 18, 94, 19, 6, 25, 23, 25, 10, 79, 9, 68, 13, 9, 3, 37, 16, 49, 15, 43, 72, 23, 9, 5, 10, 20, 37, 36, 18, 26, 40, 21, 34, 5, 5, 102, 8, 22, 33, 137, 3, 10, 47, 65, 31, 53, 16, 15, 12, 7, 14, 20, 6, 35, 3, 62, 19, 12, 7, 10, 22, 14, 6, 38, 21, 19, 5, 30, 51, 9, 32, 22, 13, 4, 22, 20, 9, 7, 25, 33, 10, 25, 8, 13, 35, 11, 15, 12, 2, 20, 29, 12, 17, 1, 31, 12, 64, 6, 20, 36, 9, 2, 31, 20, 16, 16, 31, 14, 58, 23, 42, 13, 8, 19, 10, 10, 30, 31, 31, 65, 11, 68, 1, 1, 14, 14, 5, 43, 13, 7, 35, 24, 16, 19, 19, 16, 5, 16, 21, 14, 28, 30, 25, 12, 19, 2, 25, 7, 40, 32, 20, 6, 34, 25, 72, 58, 51, 32, 16, 16, 15, 9, 28, 32, 32, 22, 17, 12, 20, 6, 15, 31, 23, 23, 6, 21, 19, 45, 24, 7, 18, 32, 59, 51, 8, 167, 14, 18, 13, 33, 30, 7, 18, 6, 6, 17, 6, 6, 21, 10, 9, 8, 12, 28, 16, 26, 31, 8, 8, 38, 4, 11, 3, 30, 31, 39, 29, 35, 18, 13, 11, 8, 26, 12, 8, 28, 16, 12, 7, 33, 11, 8, 12, 12, 35, 6, 20, 45, 38, 26, 11, 35, 12, 24, 7, 12, 15, 16, 12, 16, 16, 64, 96, 9, 31, 28, 8, 23, 218, 29, 1, 38, 23, 10, 10, 30, 11, 36, 17, 35, 23, 20, 3, 48, 13, 16, 18, 22, 39, 19, 30, 22, 24, 9, 32, 26, 23, 8, 17, 28, 42, 24, 56, 32, 7, 10, 43, 11, 6, 7, 18, 10, 28, 23, 20, 18, 9, 11, 25, 38, 8, 5, 46, 35, 6, 16, 14, 33, 32, 15, 39, 16, 35, 14, 32, 8, 17, 12, 26, 18, 27, 54, 13, 23, 11, 4, 28, 2, 11, 15, 14, 11, 19, 13, 20, 5, 27, 11, 13, 18, 6, 12, 14, 16, 28, 54, 18, 26, 16, 26, 24, 26, 23, 2, 40, 36, 23, 16, 22, 37, 94, 45, 25, 21, 11, 23, 39, 35, 7, 32, 14, 8, 17, 13, 9, 18, 25, 29, 24, 29, 46, 20, 18, 58, 21, 9, 15, 27, 4, 51, 3, 13, 9, 26, 2, 43, 12, 12, 1, 56, 25, 26, 27, 13, 26, 11, 51, 16, 26, 36, 57, 14, 7, 25, 2, 4, 20, 24, 23, 19, 12, 18, 21, 10, 5, 40, 2, 38, 24, 22, 5, 19, 16, 52, 13, 33, 36, 61, 13, 67, 39, 23, 22, 13, 7, 26, 15, 46, 4, 16, 25, 1, 26, 13, 9, 9, 1, 21, 16, 16, 33, 22, 26, 33, 53, 24, 16, 16, 6, 21, 29, 37, 7, 8, 24, 6, 6, 14, 2, 7, 31, 3, 41, 22, 20, 33, 9, 6, 31, 28, 29, 14, 18, 169, 24, 59, 19, 19, 37, 53, 13, 33, 16, 2, 8, 13, 7, 15, 9, 21, 9, 23, 20, 17, 14, 5, 18, 4, 22, 8, 27, 36, 14, 31, 16, 38, 10, 4, 12, 18, 41, 25, 27, 19, 25, 28, 13, 18, 19, 12, 19, 28, 25, 31, 32, 22, 3, 14, 42, 27, 19, 35, 36, 32, 5, 32, 4, 2, 3, 36, 14, 12, 6, 25, 21, 30, 3, 47, 25, 2, 35, 25, 15, 22, 28, 48, 18, 19, 25, 19, 22, 30, 30, 33, 45, 3, 10, 21, 4, 10, 50, 4, 3, 4, 4, 15, 14, 2, 1, 25, 19, 28, 18, 22, 6, 48, 54, 14, 8, 3, 34, 19, 5, 11, 14, 13, 5, 11, 2, 29, 26, 34, 25, 26, 34, 39, 2, 9, 25, 17, 20, 47, 16, 26, 13, 30, 25, 49, 38, 56, 33, 57, 23, 20, 22, 20, 87, 34, 1, 43, 9, 19, 26, 12, 21, 19, 42, 6, 11, 16, 14, 30, 38, 23, 11, 24, 16, 40, 7, 24, 36, 2, 30, 9, 38, 11, 41, 7, 4, 7, 6, 11, 9, 52, 11, 12, 11, 89, 16, 3, 79, 26, 25, 31, 13, 17, 55, 33, 39, 41, 26, 16, 17, 17, 9, 14, 10, 10, 18, 23, 25, 18, 16, 7, 31, 10, 26, 20, 22, 28 ...

# %% [markdown]
# Majority of comments have lenght of less than 100. So, we can use length of 128 for our language model and drop the rest of words in the sequence.

# %%
def show_sentiment_distribution(df):
    fig = go.Figure()

    groupby_sentiment = df.groupby('sentiment')['sentiment'].count()

    fig.add_trace(go.Bar(
        x=list(sorted(groupby_sentiment.index)),
        y=groupby_sentiment.tolist(),
        text=groupby_sentiment.tolist(),
        textposition='auto'
    ))

    fig.update_layout(
        title_text='Sentiment distribution',
        xaxis_title_text='Sentiment',
        yaxis_title_text='Frequency',
        bargap=0.2,
        bargroupgap=0.2)

    fig.show()
show_sentiment_distribution(df)
# Out:
# <div>                            <div id="0891c64b-659d-4b83-8533-472393f53e45" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0891c64b-659d-4b83-8533-472393f53e45")) {                    Plotly.newPlot(                        "0891c64b-659d-4b83-8533-472393f53e45",                        [{"text": ["28", "513", "2409", "1623", "987"], "textposition": "auto", "type": "bar", "x": [-2, -1, 0, 1, 2], "y": [28, 513, 2409, 1623, 987]}],                        {"bargap": 0.2, "bargroupgap": 0.2, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"o ...

# %% [markdown]
# # HANDLE IMBALANCING

# %% [markdown]
# # Train,Validation,Test split

# %%
train, test = train_test_split(df, test_size=0.1, random_state=1, stratify=df['sentiment'])
train, valid = train_test_split(train, test_size=0.1, random_state=1, stratify=train['sentiment'])

train = train.reset_index(drop=True)
valid = valid.reset_index(drop=True)
test = test.reset_index(drop=True)

x_train, y_train = train['comment'].values.tolist(), train['sentiment'].values.tolist()
x_valid, y_valid = valid['comment'].values.tolist(), valid['sentiment'].values.tolist()
x_test, y_test = test['comment'].values.tolist(), test['sentiment'].values.tolist()

print(train.shape)
print(valid.shape)
print(test.shape)
# Out:
# (4503, 3)
# (501, 3)
# (556, 3)

# %%
train.to_csv('../Dataset/train.csv')
test.to_csv('../Dataset/test.csv')
valid.to_csv('../Dataset/valid.csv')
